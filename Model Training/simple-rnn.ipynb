# %% [markdown]
# ## Import

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from matplotlib import pyplot
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

from keras.utils.np_utils import to_categorical 
from tensorflow.keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Dense, Dropout, \
    BatchNormalization, Flatten, SimpleRNN
# from scikeras.wrappers import KerasClassifier
from keras.wrappers.scikit_learn import KerasClassifier
from keras.models import load_model

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import roc_curve, roc_auc_score, auc
from sklearn.preprocessing import LabelBinarizer

from sklearn.metrics import roc_curve, auc

from itertools import cycle
from scipy import interp
from scipy.optimize import brentq
from scipy.interpolate import interp1d

N_FEATURES = 51
TIMESTEPS = 1
DATASET_LINK = "3976184250-1655049260.csv"
TEST_DATA_LINK = "3976184250-1655049260-test.csv"

# random seed for reproducibility
SEED = 123

# %% [markdown]
# ### LOAD DATASET
# > * Check for class imbalance

# %%
# loading of dataset
df = pd.read_csv(DATASET_LINK)
df['Subject'] = df['Subject'].str.replace('@yopmail.com','')
df['Subject'] = df['Subject'].str.replace('@gmail.com','')
df['Subject'] = df['Subject'].str.replace('alithnks','ali')

column_to_reorder = df.pop('Subject')

df.insert(0, 'Subject', column_to_reorder)

df.head()
# Out:
#   Subject                __id__        AvA       AvH       AvP  `DD.0.5`  \
# 0   aisha  32EyOh61auQrtt845qqu  30.386073  0.117320  0.207566  0.316371
# 1   aisha  4bA0GNx1E4csaTigdnUk  29.442656  0.117420  0.212496  0.349458
# 2   aisha  8XMHJ2b4PLrT9XU667dv  29.863961  0.098838  0.219027  0.282859
# 3   aisha  8eU5uqGw95a2Uao4QD08  31.369481  0.107199  0.287219  0.232834
# 4   aisha  AmDTWz3WvysQAblug2WG  30.882376  0.101829  0.261792  0.258754
#
#    `DD.1.6`  `DD.2.4`  `DD.4.8`  `DD.5.2`  ...   `Size.9`  `UD.0.5`  `UD.1.6`  \
# 0  0.525669  0.183837  0.574917  1.299633  ...  29.588976  0.316371  0.525669
# 1  3.484031  0.219371  0.813483  0.342324  ...  24.210612  0.349458  3.484031
# 2  0.284138  0.192723  0.191222  0.224901  ...  28.748535  0.282859  0.284138
# 3  0.208091  0.121858  0.141128  0.204205  ...  27.236084  0.232834  0.208091
# 4  0.216030  0.168339  0.590790  0.215137  ...  29.588976  0.258754  0.216030
#
#    `UD.2.4`  `UD.4.8`  `UD.5.2`  `UD.6.7`  `UD.7.9`  `UD.8.1`  `UD.9.3`
# 0  0.183837  0.574917  1.299633  0.333369  1.700769  0.949691  0.607718
# 1  0.219371  0.813483  0.342324  0.608039  0.625773  0.416927  0.908202
# 2  0.192723  0.191222  0.224901  0.232967  0.466518  0.207866  0.426501
# 3  0.121858  0.141128  0.204205  0.183798  0.340828  0.183782  0.442837
# 4  0.168339  0.590790  0.215137  0.226295  0.350204  0.192360  1.215338
#
# [5 rows x 53 columns]

# %%
#################################
# # check for class imbalance # #
#################################

sns.set_theme(style="darkgrid")
ax = sns.countplot(x="Subject", data=df).set_title("Class Imbalance")

# remove missing values if available
df = df.dropna()

sns.catplot(x="Subject", y="AvA", data=df)
sns.catplot(x="Subject", y="AvH", data=df)

# %% [markdown]
# ### PREPARING DATASET
# > * Split data into X and Y
# > * Convert Y into one-hot-encoding

# %%
dataset = df.values

# divide data into features X and target (classes) Y
X = dataset[:,2:].astype(float)
Y = dataset[:,0]

# convert target Y to labelbinarizer Y for model
Y = Y.reshape(-1, 1)
lb = LabelBinarizer().fit(Y)
Y = lb.transform(Y)

#################################
# # get all the encoded class # #
#################################
print("LabelBinarizer is able to decipher: ")
print(lb.classes_)
print("\n")

###########################
# # print X and Y shape # #
###########################
print("X dataset shape: " + str(X.shape))
print("Y dataset shape: " + str(Y.shape))
# Out:
# LabelBinarizer is able to decipher:
# ['aisha' 'ali' 'ramla' 'saad' 'umer']
#
#
# X dataset shape: (160, 51)
# Y dataset shape: (160, 5)

# %% [markdown]
# ### SPLITTING DATASET
# > * Split data into train and test dataset
# > * Normalisation performed based on X_train
# > * Reshaping of dataset for LSTM Timesteps

# %%
##############################################################
# # split dataset into train and test set of 0.8/0.2 ratio # #
##############################################################
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.2, random_state=SEED)


##############################################
# # normalisation and reshaping of dataset # #
##############################################
# normalisation to 0 to 1
# scaler = MinMaxScaler(feature_range=(0, 1))
# X_train = scaler.fit_transform(X_train)
# X_test = scaler.transform(X_test)

# reshaping the dataset to include LSTM Timesteps
X_train = np.asarray(X_train, dtype=np.float32)
X_train = np.reshape(X_train, (X_train.shape[0], TIMESTEPS, X_train.shape[1]))
X_test = np.asarray(X_test, dtype=np.float32)
X_test = np.reshape(X_test, (X_test.shape[0], TIMESTEPS, X_test.shape[1]))

# retrieve number of classes
n_classes = y_train.shape[1]

print("X train shape: " + str(X_train.shape))
print("Y train shape: " + str(y_train.shape))
print("X test shape: " + str(X_test.shape))
print("Y test shape: " + str(y_test.shape))
# Out:
# X train shape: (128, 1, 51)
# Y train shape: (128, 5)
# X test shape: (32, 1, 51)
# Y test shape: (32, 5)

# %% [markdown]
# ### CREATE MODEL
# > * Create base model
# > * Wrap it with KerasClassifier

# %%
# create base model
def create_base_model():
    model = Sequential()
    model.add(SimpleRNN(units=128, return_sequences=True, 
                 input_shape=(TIMESTEPS,N_FEATURES)))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(SimpleRNN(units=128, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(SimpleRNN(units=64, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    # softmax for multi-class classification
    model.add(Flatten())
    model.add(Dense(n_classes, activation='softmax'))

    model.compile(loss='categorical_crossentropy', optimizer='adam',
                metrics=['accuracy'])
    return model

# wrap model in KerasClassifier
def create_model():
    model = KerasClassifier(build_fn=create_base_model, epochs=100, 
                            batch_size=10)
    return model

# %% [markdown]
# ### INITIATE KFOLD VALIDATION
# > * evaluate best kfold validation
# > * generate loss and accuracy graph
# > * perform actual kfold validation

# %% [markdown]
# ##### evaluate suitable folds for kfold validation

# %%
# from sklearn.model_selection import LeaveOneOut
def evaluate_kfold(X_train, y_train, SEED):
    
    # evaluate the model    
    folds = range(2,11)
    means, mins, maxs = list(), list(), list()
    
    # evaluate each k value
    for k in folds:
        # define the test condition
        kfold = KFold(n_splits=k, shuffle=True, random_state=SEED)
        # evaluate k value
        model = create_model()
        scores = cross_val_score(model, X_train, y_train, cv=kfold, n_jobs=-1)
        
        k_mean = np.mean(scores)
        k_min = scores.min()
        k_max = scores.max()
        
        # report performance
        print('> folds=%d, accuracy=%.3f%% (min=%.3f%%, max=%.3f%%)' %
              (k, k_mean*100, k_min*100, k_max*100))
        
        # store mean accuracy
        means.append(k_mean)
        
        # store min and max relative to the mean
        mins.append(k_mean - k_min)
        maxs.append(k_max - k_mean)
        
    # line plot of k mean values with min/max error bars
    pyplot.errorbar(folds, means, yerr=[mins, maxs], fmt='o')
    
    # show the plot
    pyplot.show()
    
evaluate_kfold(X_train, y_train, SEED)
# Out:
# 2022-06-22 05:35:21.384394: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-22 05:35:21.384394: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/100
# Epoch 1/100
# 7/7 [==============================] - 2s 4ms/step - loss: 2.0276 - accuracy: 0.2188
# Epoch 2/100
# 7/7 [==============================] - 2s 4ms/step - loss: 1.9872 - accuracy: 0.2188
# Epoch 2/100
# 7/7 [==============================] - 0s 3ms/step - loss: 2.0066 - accuracy: 0.3438
# Epoch 3/100
# 7/7 [==============================] - 0s 3ms/step - loss: 2.1107 - accuracy: 0.2812
# Epoch 3/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.7520 - accuracy: 0.2812
# Epoch 4/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.9344 - accuracy: 0.2969
# Epoch 4/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.7772 - accuracy: 0.4062
# Epoch 5/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.5217 - accuracy: 0.3594
# Epoch 5/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.7260 - accuracy: 0.3750
# Epoch 6/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.8386 - accuracy: 0.3750
# Epoch 6/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.5527 - accuracy: 0.4688
# Epoch 7/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.2926 - accuracy: 0.4688
# Epoch 7/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.5606 - accuracy: 0.4531
# Epoch 8/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.
100
# 9/9 [==============================] - 0s 4ms/step - loss: 1.1291 - accuracy: 0.5581
# Epoch 17/100
# 9/9 [==============================] - 0s 4ms/step - loss: 1.1547 - accuracy: 0.5647
# Epoch 17/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.9133 - accuracy: 0.6000
# Epoch 18/100
# 9/9 [==============================] - 0s 4ms/step - loss: 1.0723 - accuracy: 0.5698
# Epoch 18/100
# 9/9 [==============================] - 0s 3ms/step - loss: 1.0236 - accuracy: 0.6353
# Epoch 18/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.7843 - accuracy: 0.6824
# Epoch 19/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.9685 - accuracy: 0.6047
# Epoch 19/100
# 9/9 [==============================] - 0s 4ms/step - loss: 1.0261 - accuracy: 0.5765
# Epoch 19/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.8655 - accuracy: 0.7294
# Epoch 20/100
# 9/9 [==============================] - 0s 4ms/step - loss: 1.0316 - accuracy: 0.6163
# Epoch 20/100
# 9/9 [==============================] - 0s 4ms/step - loss: 1.2157 - accuracy: 0.5176
# Epoch 20/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.8395 - accuracy: 0.6706
# Epoch 21/100
# 9/9 [==============================] - 0s 3ms/step - loss: 1.0043 - accuracy: 0.6395
# Epoch 21/100
# 9/9 [==============================] - 0s 3ms/step - loss: 1.1013 - accuracy: 0.5529
# Epoch 21/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.8857 - accuracy: 0.6588
# Epoch 22/100
# 9/9 [==============================] - 0s 4ms/step - loss: 1.0366 - accuracy: 0.6279
# Epoch 22/100
# 9/9 [==============================] - 0s 4ms/step - loss: 1.1027 - accuracy: 0.5176
# Epoch 22/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.8230 - accuracy: 0.6471
# Epoch 23/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.8946 - accuracy: 0.6395
# Epoch 23/100
# 9/9 [==============================] - 0s 4ms/step - loss: 1.0808 - accuracy: 0.5529
# Epoch 23/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.8813 - accuracy: 0.6706
# Epoch 24/100
# 9/9 [==============================] - 0s 4ms/step - loss: 1.0185 - accuracy: 0.6047
# Epoch 24/100
# 9/9 [==============================] - 0s 4ms/step - loss: 1.0279 - accuracy: 0.6471
# Epoch 24/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.9390 - accuracy: 0.6588
# Epoch 25/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.9449 - accuracy: 0.6977
# Epoch 25/100
# 9/9 [==============================] - 0s 4ms/step - loss: 1.0203 - accuracy: 0.6353
# Epoch 25/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.9717 - accuracy: 0.6118
# Epoch 26/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.9098 - accuracy: 0.6744
# Epoch 26/100
# 9/9 [==============================] - 0s 4ms/step - loss: 1.0172 - accuracy: 0.6000
# Epoch 26/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.8089 - accuracy: 0.7176
# Epoch 27/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.9635 - accuracy: 0.6163
# Epoch 27/100
# 9/9 [==============================] - 0s 4ms/step - loss: 1.0551 - accuracy: 0.5765
# Epoch 27/100
# 9/9 [==============================] - 0s 4ms/step - loss: 1.1062 - accuracy: 0.6353
# Epoch 28/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.9298 - accuracy: 0.6163
# Epoch 28/100
# 9/9 [==============================] - 0s 4ms/step - loss: 1.0375 - accuracy: 0.6000
# Epoch 28/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.8099 - accuracy: 0.7059
# Epoch 29/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.8619 - accuracy: 0.6744
# Epoch 29/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.9218 - accuracy: 0.6353
# Epoch 29/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.8454 - accuracy: 0.6118
# Epoch 30/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.7656 - accuracy: 0.7326
# Epoch 30/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.9850 - accuracy: 0.5882
# Epoch 30/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.7580 - accuracy: 0.7529
# Epoch 31/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.8487 - accuracy: 0.6395
# Epoch 31/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.9010 - accuracy: 0.6000
# Epoch 31/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.7551 - accuracy: 0.6824
# Epoch 32/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.8792 - accuracy: 0.6512
# Epoch 32/100
# 9/9 [==============================] - 0s 4ms/step - loss: 1.2703 - accuracy: 0.5412
# Epoch 32/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.8912 - accuracy: 0.6588
# Epoch 33/100
# 9/9 [==============================] - 0s 3ms/step - loss: 1.0047 - accuracy: 0.6744
# Epoch 33/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.8655 - accuracy: 0.6588
# Epoch 33/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.8135 - accuracy: 0.7412
# Epoch 34/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.8524 - accuracy: 0.6977
# Epoch 34/100
# 9/9 [==============================] - 0s 3ms/step - loss: 1.0398 - accuracy: 0.5765
# Epoch 34/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.8040 - accuracy: 0.6471
# Epoch 35/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.9650 - accuracy: 0.7093
# Epoch 35/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.9206 - accuracy: 0.6471
# Epoch 35/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.7445 - accuracy: 0.7294
# Epoch 36/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.9555 - accuracy: 0.5930
# Epoch 36/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.8228 - accuracy: 0.6824
# Epoch 36/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.7828 - accuracy: 0.7294
# Epoch 37/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.9658 - accuracy: 0.6512
# Epoch 37/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.9166 - accuracy: 0.7412
# Epoch 37/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6516 - accuracy: 0.7647
# Epoch 38/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.8711 - accuracy: 0.6860
# Epoch 38/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.9795 - accuracy: 0.6588
# Epoch 38/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.7739 - accuracy: 0.6941
# Epoch 39/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.7408 - accuracy: 0.7558
# Epoch 39/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.9203 - accuracy: 0.6706
# Epoch 39/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.7592 - accuracy: 0.7176
# Epoch 40/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.8334 - accuracy: 0.7442
# Epoch 40/100
# 9/9 [==============================] - 0s 3ms/step - loss: 1.0432 - accuracy: 0.6588
# Epoch 40/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.7287 - accuracy: 0.6824
# Epoch 41/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.8421 - accuracy: 0.7326
# Epoch 41/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.8370 - accuracy: 0.6588
# Epoch 41/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6422 - accuracy: 0.7176
# Epoch 42/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.7063 - accuracy: 0.7558
# Epoch 42/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.8563 - accuracy: 0.6471
# Epoch 42/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.7739 - accuracy: 0.6941
# Epoch 43/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.7696 - accuracy: 0.7326
# Epoch 43/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.8178 - accuracy: 0.6706
# Epoch 43/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6697 - accuracy: 0.7529
# Epoch 44/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.7265 - accuracy: 0.6744
# Epoch 44/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.7662 - accuracy: 0.7059
# Epoch 44/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6068 - accuracy: 0.7882
# Epoch 45/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.8600 - accuracy: 0.7093
# Epoch 45/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.8187 - accuracy: 0.6706
# Epoch 45/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6224 - accuracy: 0.7529
# Epoch 46/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.7290 - accuracy: 0.7209
# Epoch 46/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.8063 - accuracy: 0.7412
# Epoch 46/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6788 - accuracy: 0.7647
# 1/9 [==>...........................] - ETA: 0s - loss: 0.5693 - accuracy: 0.8000Epoch 47/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.7416 - accuracy: 0.7442
# Epoch 47/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.8245 - accuracy: 0.6471
# Epoch 47/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.7350 - accuracy: 0.6941
# Epoch 48/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.7018 - accuracy: 0.7674
# Epoch 48/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.7263 - accuracy: 0.7412
# Epoch 48/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.7918 - accuracy: 0.6471
# Epoch 49/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6591 - accuracy: 0.7442
# Epoch 49/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.7979 - accuracy: 0.7412
# Epoch 49/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6693 - accuracy: 0.7412
# 1/9 [==>...........................] - ETA: 0s - loss: 0.8931 - accuracy: 0.7000Epoch 50/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6626 - accuracy: 0.8023
# Epoch 50/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.7350 - accuracy: 0.7059
# Epoch 50/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6082 - accuracy: 0.7529
# Epoch 51/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6736 - accuracy: 0.7442
# Epoch 51/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.7820 - accuracy: 0.7765
# Epoch 51/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6843 - accuracy: 0.7529
# Epoch 52/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.8573 - accuracy: 0.7093
# Epoch 52/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.7564 - accuracy: 0.6941
# Epoch 52/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.7759 - accuracy: 0.6588
# Epoch 53/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.8493 - accuracy: 0.6977
# Epoch 53/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.7591 - accuracy: 0.7529
# Epoch 53/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5867 - accuracy: 0.7294
# Epoch 54/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.7294 - accuracy: 0.7326
# Epoch 54/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6498 - accuracy: 0.8118
# Epoch 54/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.7024 - accuracy: 0.7529
# Epoch 55/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6902 - accuracy: 0.7209
# Epoch 55/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6333 - accuracy: 0.8000
# Epoch 55/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6606 - accuracy: 0.7294
# Epoch 56/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6546 - accuracy: 0.7442
# Epoch 56/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.7275 - accuracy: 0.7176
# Epoch 56/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.8072 - accuracy: 0.7294
# Epoch 57/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6422 - accuracy: 0.7558
# Epoch 57/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.7321 - accuracy: 0.7176
# Epoch 57/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5987 - accuracy: 0.7765
# Epoch 58/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.7718 - accuracy: 0.7209
# Epoch 58/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6900 - accuracy: 0.7647
# Epoch 58/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.7181 - accuracy: 0.7176
# Epoch 59/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5868 - accuracy: 0.8023
# Epoch 59/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.8002 - accuracy: 0.7059
# Epoch 59/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5759 - accuracy: 0.7765
# Epoch 60/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6133 - accuracy: 0.7326
# Epoch 60/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5136 - accuracy: 0.8588
# Epoch 60/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6858 - accuracy: 0.7176
# Epoch 61/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.8453 - accuracy: 0.6628
# Epoch 61/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.7858 - accuracy: 0.7412
# Epoch 61/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4535 - accuracy: 0.8471
# Epoch 62/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6926 - accuracy: 0.7093
# Epoch 62/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6842 - accuracy: 0.8000
# Epoch 62/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5958 - accuracy: 0.7529
# Epoch 63/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6794 - accuracy: 0.7326
# Epoch 63/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.7282 - accuracy: 0.7176
# 9/9 [==============================] - 0s 4ms/step - loss: 0.7525 - accuracy: 0.7059
# Epoch 64/100
# Epoch 63/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5744 - accuracy: 0.7674
# Epoch 64/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6097 - accuracy: 0.7529
# Epoch 65/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.7156 - accuracy: 0.7765
# Epoch 64/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6389 - accuracy: 0.7442
# Epoch 65/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6115 - accuracy: 0.7882
# Epoch 66/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.7138 - accuracy: 0.7326
# Epoch 66/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6477 - accuracy: 0.7529
# Epoch 65/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.7158 - accuracy: 0.7647
# Epoch 67/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5628 - accuracy: 0.7674
# Epoch 67/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5812 - accuracy: 0.7765
# Epoch 68/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6837 - accuracy: 0.7765
# Epoch 66/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6892 - accuracy: 0.7674
# Epoch 68/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.7338 - accuracy: 0.7647
# Epoch 69/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.7377 - accuracy: 0.7529
# Epoch 67/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5792 - accuracy: 0.8140
# Epoch 69/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4198 - accuracy: 0.8706
# Epoch 70/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5706 - accuracy: 0.8471
# Epoch 68/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6764 - accuracy: 0.6860
# Epoch 70/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6073 - accuracy: 0.7647
# Epoch 71/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.7394 - accuracy: 0.7294
# Epoch 69/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.7834 - accuracy: 0.7558
# Epoch 71/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.7442 - accuracy: 0.7882
# Epoch 72/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6874 - accuracy: 0.7176
# Epoch 70/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.8002 - accuracy: 0.6977
# Epoch 72/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6282 - accuracy: 0.7529
# Epoch 73/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.7786 - accuracy: 0.6941
# Epoch 71/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6400 - accuracy: 0.7442
# Epoch 73/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5476 - accuracy: 0.8118
# Epoch 74/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.7263 - accuracy: 0.6941
# Epoch 72/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6816 - accuracy: 0.7558
# Epoch 74/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5544 - accuracy: 0.8118
# Epoch 75/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.7138 - accuracy: 0.7412
# Epoch 73/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5515 - accuracy: 0.8023
# Epoch 75/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5893 - accuracy: 0.8000
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6784 - accuracy: 0.7294
# Epoch 74/100
# Epoch 76/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6464 - accuracy: 0.6860
# Epoch 76/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6198 - accuracy: 0.7647
# Epoch 77/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6737 - accuracy: 0.7176
# Epoch 75/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.7299 - accuracy: 0.7442
# Epoch 77/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5031 - accuracy: 0.7882
# Epoch 78/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5949 - accuracy: 0.7882
# Epoch 76/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6366 - accuracy: 0.7791
# Epoch 78/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.7362 - accuracy: 0.6941
# Epoch 79/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.7893 - accuracy: 0.7176
# Epoch 77/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6331 - accuracy: 0.7442
# Epoch 79/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5560 - accuracy: 0.8000
# Epoch 80/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.7466 - accuracy: 0.7647
# Epoch 78/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5534 - accuracy: 0.7326
# Epoch 80/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3928 - accuracy: 0.8588
# Epoch 81/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5401 - accuracy: 0.8353
# Epoch 79/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5990 - accuracy: 0.7791
# Epoch 81/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.5242 - accuracy: 0.8000
# Epoch 82/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6815 - accuracy: 0.7176
# Epoch 80/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6842 - accuracy: 0.7209
# Epoch 82/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6686 - accuracy: 0.7294
# Epoch 83/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.8894 - accuracy: 0.6941
# Epoch 81/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6384 - accuracy: 0.7791
# Epoch 83/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6128 - accuracy: 0.7882
# Epoch 84/100
# 9/9 [==============================] - 0s 3ms/step - loss: 0.
100
# 12/12 [==============================] - 0s 9ms/step - loss: 0.5644 - accuracy: 0.7845
# Epoch 97/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.6135 - accuracy: 0.8261
# Epoch 99/100
# 12/12 [==============================] - 0s 8ms/step - loss: 0.5484 - accuracy: 0.8000
# 12/12 [==============================] - 0s 7ms/step - loss: 0.5559 - accuracy: 0.8087
# Epoch 98/100
# Epoch 98/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.5442 - accuracy: 0.8534
#  1/12 [=>............................] - ETA: 0s - loss: 0.3396 - accuracy: 0.9000Epoch 98/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.7713 - accuracy: 0.7652
# Epoch 87/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6141 - accuracy: 0.7652
# 12/12 [==============================] - 0s 7ms/step - loss: 0.5646 - accuracy: 0.7931
# Epoch 100/100
# Epoch 98/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.5983 - accuracy: 0.7913
# Epoch 99/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.3640 - accuracy: 0.8621
# 12/12 [==============================] - 0s 7ms/step - loss: 0.7409 - accuracy: 0.7478
# Epoch 99/100
# Epoch 99/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4543 - accuracy: 0.8707
# Epoch 99/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.6295 - accuracy: 0.7565
# 12/12 [==============================] - 0s 7ms/step - loss: 0.7696 - accuracy: 0.7130
# Epoch 88/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4128 - accuracy: 0.8522
# Epoch 100/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7441 - accuracy: 0.7739
# Epoch 100/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.4715 - accuracy: 0.8103
# Epoch 100/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.5535 - accuracy: 0.7931
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4686 - accuracy: 0.8174
# Epoch 100/100
# Epoch 89/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.5462 - accuracy: 0.7913
# 12/12 [==============================] - 0s 6ms/step - loss: 0.5833 - accuracy: 0.7739
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4917 - accuracy: 0.8276
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6125 - accuracy: 0.7652
# Epoch 90/100
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6070 - accuracy: 0.8103
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5919 - accuracy: 0.7913
# Epoch 91/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6129 - accuracy: 0.7826
# Epoch 92/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4780 - accuracy: 0.8261
# Epoch 93/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7183 - accuracy: 0.7391
# Epoch 94/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7249 - accuracy: 0.7478
# Epoch 95/100
# 12/12 [==============================] - 0s 7ms/step - loss: 0.5820 - accuracy: 0.7739
# Epoch 96/100
# 12/12 [==============================] - 0s 10ms/step - loss: 0.5585 - accuracy: 0.8000
# Epoch 97/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5472 - accuracy: 0.8087
# Epoch 98/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5282 - accuracy: 0.8174
# Epoch 99/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4531 - accuracy: 0.8261
# Epoch 100/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5424 - accuracy: 0.8348
# 2/2 [==============================] - 1s 3ms/step - loss: 1.5234 - accuracy: 0.7692
# 2/2 [==============================] - 1s 3ms/step - loss: 0.6772 - accuracy: 0.8462
# 2/2 [==============================] - 1s 3ms/step - loss: 0.4609 - accuracy: 0.9231
# 2/2 [==============================] - 1s 3ms/step - loss: 0.5681 - accuracy: 0.8462
# 2/2 [==============================] - 1s 3ms/step - loss: 0.6624 - accuracy: 0.8462
# 2/2 [==============================] - 1s 2ms/step - loss: 0.7604 - accuracy: 0.8462
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x12d3704c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x12e7789d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 12 calls to <function Model.make_test_function.<locals>.test_function at 0x128b549d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 1s 2ms/step - loss: 0.5166 - accuracy: 0.7500
# 2/2 [==============================] - 1s 2ms/step - loss: 1.0722 - accuracy: 0.6923
# 2/2 [==============================] - 1s 2ms/step - loss: 0.2943 - accuracy: 0.8333
# 2/2 [==============================] - 1s 2ms/step - loss: 1.2837 - accuracy: 0.7692
# > folds=10, accuracy=81.218% (min=69.231%, max=92.308%)

# %% [markdown]
# ##### generate kfold validation accuracy and loss

# %%
##################################################
# # evaluate kfold model for accuracy and loss # #
##################################################
def evaluate_kfold_model(X_train, y_train, SEED):
    scores, histories = list(), list()
    # create model
    model = create_model()
    # prepare cross validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=SEED)
    # enumerate splits
    for train_ix, test_ix in kfold.split(X_train):
        # select rows for train and test
        trainX, trainY, testX, testY = X_train[train_ix], y_train[train_ix], X_train[test_ix], y_train[test_ix]
        # fit model
        history = model.fit(trainX, trainY, epochs=100, batch_size=10, validation_data=(testX, testY), verbose=0)
        
        # evaluate model
        y_pred = model.predict(testX)
        y_pred = to_categorical(y_pred)

        # evaluate predictions
        acc = accuracy_score(testY, y_pred)
        print("Testing accuracy: %.3f%%" % (acc*100))

        # stores scores and histories
        scores.append(acc)
        histories.append(history)

    for i in range(len(histories)):
        # plot loss
        f1 = plt.figure(1)
        plt.title('Categorical Cross-Entropy Loss')
        plt.plot(histories[i].history['loss'], color='blue')
        plt.plot(histories[i].history['val_loss'], color='orange')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper right')

        # plot accuracy
        f2 = plt.figure(2)
        plt.title('Classification Accuracy')
        plt.plot(histories[i].history['accuracy'], color='blue')
        plt.plot(histories[i].history['val_accuracy'], color='orange')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='lower right')

    # print summary
    print('Accuracy: Mean=%.3f Std=%.3f, n=%d' % (np.mean(scores)*100, np.std(scores)*100, len(scores)))
    # box and whisker plots of results
    f3 = plt.figure(3)
    plt.title('Box and Whisker Plot of Accuracy Scores')
    plt.ylabel('accuracy')
    plt.xlabel('model')
    plt.boxplot(scores)
    plt.show()
    
evaluate_kfold_model(X_train, y_train, SEED)
# Out:
# 2022-06-22 05:37:40.686172: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 1/1 [==============================] - 0s 281ms/step
# Testing accuracy: 69.231%
# 1/1 [==============================] - 0s 275ms/step
# Testing accuracy: 92.308%
# 1/1 [==============================] - 0s 253ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/aliabduljabbar/Developer/Tolerance-master/lb_keystroke_rnn.ipynb Cell 17' in <module>
#      <a href='vscode-notebook-cell:/Users/aliabduljabbar/Developer/Tolerance-master/lb_keystroke_rnn.ipynb#ch0000016?line=54'>55</a>     plt.boxplot(scores)
#      <a href='vscode-notebook-cell:/Users/aliabduljabbar/Developer/Tolerance-master/lb_keystroke_rnn.ipynb#ch0000016?line=55'>56</a>     plt.show()
# ---> <a href='vscode-notebook-cell:/Users/aliabduljabbar/Developer/Tolerance-master/lb_keystroke_rnn.ipynb#ch0000016?line=57'>58</a> evaluate_kfold_model(X_train, y_train, SEED)
#
# /Users/aliabduljabbar/Developer/Tolerance-master/lb_keystroke_rnn.ipynb Cell 17' in evaluate_kfold_model(X_train, y_train, SEED)
#      <a href='vscode-notebook-cell:/Users/aliabduljabbar/Developer/Tolerance-master/lb_keystroke_rnn.ipynb#ch0000016?line=18'>19</a> y_pred = to_categorical(y_pred)
#      <a href='vscode-notebook-cell:/Users/aliabduljabbar/Developer/Tolerance-master/lb_keystroke_rnn.ipynb#ch0000016?line=20'>21</a> # evaluate predictions
# ---> <a href='vscode-notebook-cell:/Users/aliabduljabbar/Developer/Tolerance-master/lb_keystroke_rnn.ipynb#ch0000016?line=21'>22</a> acc = accuracy_score(testY, y_pred)
#      <a href='vscode-notebook-cell:/Users/aliabduljabbar/Developer/Tolerance-master/lb_keystroke_rnn.ipynb#ch0000016?line=22'>23</a> print("Testing accuracy: %.3f%%" % (acc*100))
#      <a href='vscode-notebook-cell:/Users/aliabduljabbar/Developer/Tolerance-master/lb_keystroke_rnn.ipynb#ch0000016?line=24'>25</a> # stores scores and histories
#
# File ~/Library/Python/3.8/lib/python/site-packages/sklearn/metrics/_classification.py:214, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     <a href='file:///Users/aliabduljabbar/Library/Python/3.8/lib/python/site-packages/sklearn/metrics/_classification.py?line=211'>212</a> check_consistent_length(y_true, y_pred, sample_weight)
#     <a href='file:///Users/aliabduljabbar/Library/Python/3.8/lib/python/site-packages/sklearn/metrics/_classification.py?line=212'>213</a> if y_type.startswith("multilabel"):
# --> <a href='file:///Users/aliabduljabbar/Library/Python/3.8/lib/python/site-packages/sklearn/metrics/_classification.py?line=213'>214</a>     differing_labels = count_nonzero(y_true - y_pred, axis=1)
#     <a href='file:///Users/aliabduljabbar/Library/Python/3.8/lib/python/site-packages/sklearn/metrics/_classification.py?line=214'>215</a>     score = differing_labels == 0
#     <a href='file:///Users/aliabduljabbar/Library/Python/3.8/lib/python/site-packages/sklearn/metrics/_classification.py?line=215'>216</a> else:
#
# File ~/Library/Python/3.8/lib/python/site-packages/scipy/sparse/base.py:433, in spmatrix.__sub__(self, other)
#     <a href='file:///Users/aliabduljabbar/Library/Python/3.8/lib/python/site-packages/scipy/sparse/base.py?line=430'>431</a> elif isspmatrix(other):
#     <a href='file:///Users/aliabduljabbar/Library/Python/3.8/lib/python/site-packages/scipy/sparse/base.py?line=431'>432</a>     if other.shape != self.shape:
# --> <a href='file:///Users/aliabduljabbar/Library/Python/3.8/lib/python/site-packages/scipy/sparse/base.py?line=432'>433</a>         raise ValueError("inconsistent shapes")
#     <a href='file:///Users/aliabduljabbar/Library/Python/3.8/lib/python/site-packages/scipy/sparse/base.py?line=433'>434</a>     return self._sub_sparse(other)
#     <a href='file:///Users/aliabduljabbar/Library/Python/3.8/lib/python/site-packages/scipy/sparse/base.py?line=434'>435</a> elif isdense(other):
#
# ValueError: inconsistent shapes

# %% [markdown]
# ##### perform actual KFold Validation

# %%
# create model
model = create_model()

n_folds = 2
kfold = KFold(n_splits=n_folds, shuffle=True,
              random_state=SEED)

valid_score = cross_val_score(model, X_train, y_train, 
                          cv=kfold, error_score="raise", verbose=0)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 2s 2ms/step - loss: 2.2179 - accuracy: 0.1250
# Epoch 2/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.8931 - accuracy: 0.3750
# Epoch 3/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.6014 - accuracy: 0.3125
# Epoch 4/100
# 7/7 [==============================] - 0s 4ms/step - loss: 1.7839 - accuracy: 0.3281
# Epoch 5/100
# 7/7 [==============================] - 0s 4ms/step - loss: 1.5181 - accuracy: 0.4062
# Epoch 6/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.5559 - accuracy: 0.4531
# Epoch 7/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.5390 - accuracy: 0.4062
# Epoch 8/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.5484 - accuracy: 0.3906
# Epoch 9/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.3159 - accuracy: 0.5312
# Epoch 10/100
# 7/7 [==============================] - 0s 4ms/step - loss: 1.4240 - accuracy: 0.4375
# Epoch 11/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.5004 - accuracy: 0.3906
# Epoch 12/100
# 7/7 [==============================] - 0s 4ms/step - loss: 1.5359 - accuracy: 0.3750
# Epoch 13/100
# 7/7 [==============================] - 0s 4ms/step - loss: 1.4646 - accuracy: 0.4375
# Epoch 14/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.4574 - accuracy: 0.4219
# Epoch 15/100
# 7/7 [==============================] - 0s 4ms/step - loss: 1.3247 - accuracy: 0.4688
# Epoch 16/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1454 - accuracy: 0.4844
# Epoch 17/100
# 7/7 [==============================] - 0s 4ms/step - loss: 1.2775 - accuracy: 0.4375
# Epoch 18/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.3525 - accuracy: 0.4531
# Epoch 19/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.2891 - accuracy: 0.5156
# Epoch 20/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.2236 - accuracy: 0.5000
# Epoch 21/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0864 - accuracy: 0.5781
# Epoch 22/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1911 - accuracy: 0.4844
# Epoch 23/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1525 - accuracy: 0.5781
# Epoch 24/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1656 - accuracy: 0.5469
# Epoch 25/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0363 - accuracy: 0.6094
# Epoch 26/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1528 - accuracy: 0.5156
# Epoch 27/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1557 - accuracy: 0.4688
# Epoch 28/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.2071 - accuracy: 0.5938
# Epoch 29/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1210 - accuracy: 0.5469
# Epoch 30/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0749 - accuracy: 0.5625
# Epoch 31/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9658 - accuracy: 0.6562
# Epoch 32/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8299 - accuracy: 0.6406
# Epoch 33/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0075 - accuracy: 0.5781
# Epoch 34/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8975 - accuracy: 0.6875
# Epoch 35/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0760 - accuracy: 0.5781
# Epoch 36/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9750 - accuracy: 0.6094
# Epoch 37/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9462 - accuracy: 0.6094
# Epoch 38/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7832 - accuracy: 0.6562
# Epoch 39/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9033 - accuracy: 0.7344
# Epoch 40/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8967 - accuracy: 0.6406
# Epoch 41/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8375 - accuracy: 0.6250
# Epoch 42/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7566 - accuracy: 0.7500
# Epoch 43/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9181 - accuracy: 0.6875
# Epoch 44/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8583 - accuracy: 0.7188
# Epoch 45/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8869 - accuracy: 0.6250
# Epoch 46/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7903 - accuracy: 0.7812
# Epoch 47/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8126 - accuracy: 0.7188
# Epoch 48/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7752 - accuracy: 0.6875
# Epoch 49/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7557 - accuracy: 0.7344
# Epoch 50/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8020 - accuracy: 0.6719
# Epoch 51/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.8234 - accuracy: 0.7188
# Epoch 52/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9644 - accuracy: 0.6250
# Epoch 53/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9574 - accuracy: 0.6562
# Epoch 54/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9462 - accuracy: 0.6562
# Epoch 55/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8412 - accuracy: 0.7031
# Epoch 56/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7605 - accuracy: 0.7031
# Epoch 57/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9115 - accuracy: 0.6562
# Epoch 58/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7882 - accuracy: 0.7031
# Epoch 59/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6964 - accuracy: 0.7188
# Epoch 60/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7017 - accuracy: 0.7344
# Epoch 61/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8958 - accuracy: 0.6875
# Epoch 62/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8139 - accuracy: 0.7344
# Epoch 63/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7689 - accuracy: 0.6719
# Epoch 64/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7528 - accuracy: 0.7344
# Epoch 65/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8383 - accuracy: 0.6250
# Epoch 66/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7293 - accuracy: 0.7188
# Epoch 67/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7145 - accuracy: 0.7188
# Epoch 68/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7914 - accuracy: 0.6406
# Epoch 69/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8188 - accuracy: 0.6562
# Epoch 70/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7182 - accuracy: 0.7031
# Epoch 71/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0079 - accuracy: 0.5781
# Epoch 72/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7578 - accuracy: 0.7031
# Epoch 73/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7906 - accuracy: 0.6719
# Epoch 74/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7182 - accuracy: 0.7188
# Epoch 75/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.
100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7009 - accuracy: 0.7344
# Epoch 69/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9050 - accuracy: 0.6562
# Epoch 70/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8791 - accuracy: 0.7188
# Epoch 71/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6952 - accuracy: 0.7344
# Epoch 72/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8818 - accuracy: 0.5781
# Epoch 73/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8067 - accuracy: 0.6406
# Epoch 74/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6131 - accuracy: 0.7656
# Epoch 75/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9025 - accuracy: 0.6562
# Epoch 76/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9280 - accuracy: 0.6250
# Epoch 77/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8128 - accuracy: 0.6875
# Epoch 78/100
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0502 - accuracy: 0.5938
# Epoch 79/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7838 - accuracy: 0.7344
# Epoch 80/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8689 - accuracy: 0.6562
# Epoch 81/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7684 - accuracy: 0.7344
# Epoch 82/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6911 - accuracy: 0.7500
# Epoch 83/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7554 - accuracy: 0.6562
# Epoch 84/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6879 - accuracy: 0.7031
# Epoch 85/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6145 - accuracy: 0.7656
# Epoch 86/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8876 - accuracy: 0.7344
# Epoch 87/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7522 - accuracy: 0.7500
# Epoch 88/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6649 - accuracy: 0.7031
# Epoch 89/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7327 - accuracy: 0.7344
# Epoch 90/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5740 - accuracy: 0.8281
# Epoch 91/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6289 - accuracy: 0.8125
# Epoch 92/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6009 - accuracy: 0.8125
# Epoch 93/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7838 - accuracy: 0.6875
# Epoch 94/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8171 - accuracy: 0.6406
# Epoch 95/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9487 - accuracy: 0.5312
# Epoch 96/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6541 - accuracy: 0.7969
# Epoch 97/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7560 - accuracy: 0.6875
# Epoch 98/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8282 - accuracy: 0.7188
# Epoch 99/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6807 - accuracy: 0.7500
# Epoch 100/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5900 - accuracy: 0.8281
# 7/7 [==============================] - 0s 1ms/step - loss: 1.1282 - accuracy: 0.6406

# %% [markdown]
# ##### get validation accuracy

# %%
print("Validation Accuracy of %.2f%% (with standard deviation of %.2f%%)" % 
      (valid_score.mean()*100, valid_score.std()*100))
# Out:
# Validation Accuracy of 64.06% (with standard deviation of 0.00%)

# %% [markdown]
# ### FIT MODEL FOR TESTING
# > * fit the model
# > * view the accuracy and loss graph
# > * view model summary

# %%
#####################
# # fit the model # #
#####################
es = EarlyStopping(monitor='loss', mode='min', min_delta=0.001, patience=50,
                   verbose=1)
history = model.fit(X_train, y_train, callbacks=es, verbose=1)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 2s 3ms/step - loss: 2.1277 - accuracy: 0.1875
# Epoch 2/100
# 13/13 [==============================] - 0s 6ms/step - loss: 1.8893 - accuracy: 0.2656
# Epoch 3/100
# 13/13 [==============================] - 0s 4ms/step - loss: 1.5219 - accuracy: 0.4375
# Epoch 4/100
# 13/13 [==============================] - 0s 4ms/step - loss: 1.3366 - accuracy: 0.4922
# Epoch 5/100
# 13/13 [==============================] - 0s 3ms/step - loss: 1.3406 - accuracy: 0.5156
# Epoch 6/100
# 13/13 [==============================] - 0s 3ms/step - loss: 1.2353 - accuracy: 0.5469
# Epoch 7/100
# 13/13 [==============================] - 0s 3ms/step - loss: 1.3134 - accuracy: 0.4922
# Epoch 8/100
# 13/13 [==============================] - 0s 3ms/step - loss: 1.1785 - accuracy: 0.5391
# Epoch 9/100
# 13/13 [==============================] - 0s 3ms/step - loss: 1.1085 - accuracy: 0.5703
# Epoch 10/100
# 13/13 [==============================] - 0s 3ms/step - loss: 1.0568 - accuracy: 0.6484
# Epoch 11/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.9861 - accuracy: 0.5781
# Epoch 12/100
# 13/13 [==============================] - 0s 3ms/step - loss: 1.0907 - accuracy: 0.5938
# Epoch 13/100
# 13/13 [==============================] - 0s 3ms/step - loss: 1.1001 - accuracy: 0.5859
# Epoch 14/100
# 13/13 [==============================] - 0s 3ms/step - loss: 1.0895 - accuracy: 0.5938
# Epoch 15/100
# 13/13 [==============================] - 0s 3ms/step - loss: 1.0637 - accuracy: 0.6406
# Epoch 16/100
# 13/13 [==============================] - 0s 3ms/step - loss: 1.0392 - accuracy: 0.6172
# Epoch 17/100
# 13/13 [==============================] - 0s 3ms/step - loss: 1.1454 - accuracy: 0.6016
# Epoch 18/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.8882 - accuracy: 0.6719
# Epoch 19/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.8566 - accuracy: 0.6641
# Epoch 20/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.9331 - accuracy: 0.6875
# Epoch 21/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.9710 - accuracy: 0.6172
# Epoch 22/100
# 13/13 [==============================] - 0s 3ms/step - loss: 1.0106 - accuracy: 0.5781
# Epoch 23/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.8247 - accuracy: 0.6953
# Epoch 24/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.9326 - accuracy: 0.6562
# Epoch 25/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.8292 - accuracy: 0.7031
# Epoch 26/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.9622 - accuracy: 0.6406
# Epoch 27/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.8165 - accuracy: 0.7422
# Epoch 28/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.7551 - accuracy: 0.7578
# Epoch 29/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.8560 - accuracy: 0.6953
# Epoch 30/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6045 - accuracy: 0.7734
# Epoch 31/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.7569 - accuracy: 0.7344
# Epoch 32/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.7908 - accuracy: 0.6641
# Epoch 33/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.8325 - accuracy: 0.6797
# Epoch 34/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.7514 - accuracy: 0.7500
# Epoch 35/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.7645 - accuracy: 0.7031
# Epoch 36/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.7380 - accuracy: 0.7188
# Epoch 37/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.8064 - accuracy: 0.7031
# Epoch 38/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.7979 - accuracy: 0.7500
# Epoch 39/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.7680 - accuracy: 0.7500
# Epoch 40/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6985 - accuracy: 0.7500
# Epoch 41/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.7345 - accuracy: 0.7031
# Epoch 42/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.8204 - accuracy: 0.7031
# Epoch 43/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.7010 - accuracy: 0.7500
# Epoch 44/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.7947 - accuracy: 0.7109
# Epoch 45/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.8524 - accuracy: 0.6953
# Epoch 46/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6512 - accuracy: 0.7891
# Epoch 47/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6543 - accuracy: 0.7266
# Epoch 48/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6491 - accuracy: 0.7344
# Epoch 49/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.7482 - accuracy: 0.7500
# Epoch 50/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.7036 - accuracy: 0.7500
# Epoch 51/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6768 - accuracy: 0.7812
# Epoch 52/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.7036 - accuracy: 0.7344
# Epoch 53/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.7250 - accuracy: 0.7266
# Epoch 54/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6624 - accuracy: 0.7578
# Epoch 55/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.4973 - accuracy: 0.8047
# Epoch 56/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5653 - accuracy: 0.7812
# Epoch 57/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.7618 - accuracy: 0.7188
# Epoch 58/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5510 - accuracy: 0.7891
# Epoch 59/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6958 - accuracy: 0.7812
# Epoch 60/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5781 - accuracy: 0.8125
# Epoch 61/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5622 - accuracy: 0.7578
# Epoch 62/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.4275 - accuracy: 0.8281
# Epoch 63/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5151 - accuracy: 0.8203
# Epoch 64/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5799 - accuracy: 0.7969
# Epoch 65/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6437 - accuracy: 0.7891
# Epoch 66/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5983 - accuracy: 0.7969
# Epoch 67/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5909 - accuracy: 0.8047
# Epoch 68/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.4887 - accuracy: 0.8203
# Epoch 69/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6418 - accuracy: 0.7812
# Epoch 70/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5066 - accuracy: 0.8203
# Epoch 71/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.4930 - accuracy: 0.8125
# Epoch 72/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5275 - accuracy: 0.8281
# Epoch 73/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5941 - accuracy: 0.7656
# Epoch 74/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4466 - accuracy: 0.8359
# Epoch 75/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5970 - accuracy: 0.7812
# Epoch 76/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5439 - accuracy: 0.8359
# Epoch 77/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.4977 - accuracy: 0.8281
# Epoch 78/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6393 - accuracy: 0.7812
# Epoch 79/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.4903 - accuracy: 0.8281
# Epoch 80/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6226 - accuracy: 0.7812
# Epoch 81/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.4862 - accuracy: 0.8125
# Epoch 82/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.4972 - accuracy: 0.8125
# Epoch 83/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5933 - accuracy: 0.8047
# Epoch 84/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6974 - accuracy: 0.7422
# Epoch 85/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6926 - accuracy: 0.7656
# Epoch 86/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5279 - accuracy: 0.8203
# Epoch 87/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.3514 - accuracy: 0.8984
# Epoch 88/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.4581 - accuracy: 0.7891
# Epoch 89/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4801 - accuracy: 0.8047
# Epoch 90/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.4786 - accuracy: 0.8516
# Epoch 91/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6066 - accuracy: 0.7969
# Epoch 92/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6378 - accuracy: 0.7266
# Epoch 93/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5974 - accuracy: 0.7734
# Epoch 94/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5431 - accuracy: 0.7969
# Epoch 95/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.4137 - accuracy: 0.8047
# Epoch 96/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5064 - accuracy: 0.8047
# Epoch 97/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5096 - accuracy: 0.8047
# Epoch 98/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6010 - accuracy: 0.7891
# Epoch 99/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.4956 - accuracy: 0.8359
# Epoch 100/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.4573 - accuracy: 0.8281

# %%
##########################
# # get model accuracy # #
##########################
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

######################
# # get model loss # #
######################
plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %%
##########################
# # view model summary # #
##########################
model.model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_15 (SimpleRNN)   (None, 1, 128)            23040
#
#  dropout_15 (Dropout)        (None, 1, 128)            0
#
#  batch_normalization_15 (Bat  (None, 1, 128)           512
#  chNormalization)
#
#  simple_rnn_16 (SimpleRNN)   (None, 1, 128)            32896
#
#  dropout_16 (Dropout)        (None, 1, 128)            0
#
#  batch_normalization_16 (Bat  (None, 1, 128)           512
#  chNormalization)
#
#  simple_rnn_17 (SimpleRNN)   (None, 1, 64)             12352
#
#  dropout_17 (Dropout)        (None, 1, 64)             0
#
#  batch_normalization_17 (Bat  (None, 1, 64)            256
#  chNormalization)
#
#  flatten_5 (Flatten)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 69,893
# Trainable params: 69,253
# Non-trainable params: 640
# _________________________________________________________________

# %% [markdown]
# ### MODEL TESTING
# > * get model accuracy on the test dataset
# > * generate confusion matrix
# > * generate ROC curves
# > * save the model if appropriate

# %%
y_pred = model.predict_proba(X_test)

# evaluate predictions
acc = accuracy_score(lb.inverse_transform(y_test), lb.inverse_transform(y_pred))
print("Testing accuracy: %.3f%%" % (acc*100))
# Out:
# 1/1 [==============================] - 0s 292ms/step
# Testing accuracy: 75.000%

# %% [markdown]
# ##### Confusion Matrix

# %%
# confusion matrix
cm = confusion_matrix(lb.inverse_transform(y_test), lb.inverse_transform(y_pred))
df_cm = pd.DataFrame(cm, index = [i for i in np.unique(lb.inverse_transform(y_test))],
                     columns = [i for i in np.unique(lb.inverse_transform(y_test))])

plt.figure(figsize = (10,7))
sns.heatmap(df_cm, annot=True, cmap="BuPu")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### ROC Curve (Individual)

# %%
# compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

for i in range(n_classes):
    plt.figure()
    lw = 2
    plt.plot(
        fpr[i],
        tpr[i],
        color="darkorange",
        lw=lw,
        label="ROC curve (area = %0.2f)" % roc_auc[i],
    )
    plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
    plt.xlim([-0.005, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curve (" + str(lb.classes_[i]) + ")")
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# ##### ROC Curve (Combined Plot)

# %%
# compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], thresholds = roc_curve(y_test.ravel(), y_pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# first aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
# plt.figure()
# plt.plot(
#     fpr["micro"],
#     tpr["micro"],
#     label="micro-average ROC curve (area = {0:0.2f})".format(roc_auc["micro"]),
#     color="deeppink",
#     linestyle=":",
#     linewidth=4,
# )

# plt.plot(
#     fpr["macro"],
#     tpr["macro"],
#     label="macro-average ROC curve (area = {0:0.2f})".format(roc_auc["macro"]),
#     color="navy",
#     linestyle=":",
#     linewidth=4,
# )

colors = cycle(["aqua", "darkorange", "cornflowerblue", "lightgreen", "purple"])
for i, color in zip(range(n_classes), colors):
    plt.plot(
        fpr[i],
        tpr[i],
        color=color,
        lw=lw,
        label="ROC curve of class {0} (area = {1:0.2f})".format(lb.classes_[i], roc_auc[i]),
    )

plt.plot([0, 1], [0, 1], "k--", lw=lw)
plt.xlim([-0.005, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve (Multiclass)")
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ##### ROC Curve (Average out)

# %%
fpr, tpr, threshold = roc_curve(y_test.ravel(), y_pred.ravel())

# calculate equal-error-rate
eer = brentq(lambda x : 1. - x - interp1d(fpr, tpr)(x), 0., 1.)

plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr, label='AUC = {:.3f}, EER = {:.3f}'.format(auc(fpr, tpr), eer))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('Average ROC Curve')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### FIT AND SAVE MODEL
# > * fitting of model
# > * get accuracy and loss of model
# > * saving model

# %%
##############################################
# # normalisation and reshaping of dataset # #
##############################################
# loading of dataset
df = pd.read_csv(DATASET_LINK)

df['Subject'] = df['Subject'].str.replace('@yopmail.com','')
df['Subject'] = df['Subject'].str.replace('@gmail.com','')
df['Subject'] = df['Subject'].str.replace('alithnks','ali')

column_to_reorder = df.pop('Subject')

df.insert(0, 'Subject', column_to_reorder)
df.head()
dataset = df.values

# divide data into features X and target (classes) Y
X = dataset[:,2:].astype(float)
Y = dataset[:,0]

# convert target Y to labelbinarizer Y for model
Y = Y.reshape(-1, 1)
lb = LabelBinarizer().fit(Y)
Y = lb.transform(Y)

# # normalisation to 0 to 1
# scaler = MinMaxScaler(feature_range=(0, 1))
# X = scaler.fit_transform(X)


# reshaping the dataset to include LSTM Timesteps
X = np.asarray(X, dtype=np.float32)
X = np.reshape(X, (X.shape[0], TIMESTEPS, X.shape[1]))

#####################
# # fit the model # #
#####################

model = create_model()
es = EarlyStopping(monitor='loss', mode='min', min_delta=0.001, patience=50,
                   verbose=0)
history = model.fit(X, Y, callbacks=es)
# Out:
# Epoch 1/100
# 16/16 [==============================] - 2s 6ms/step - loss: 2.0022 - accuracy: 0.3187
# Epoch 2/100
# 16/16 [==============================] - 0s 3ms/step - loss: 1.5531 - accuracy: 0.3875
# Epoch 3/100
# 16/16 [==============================] - 0s 3ms/step - loss: 1.3690 - accuracy: 0.5063
# Epoch 4/100
# 16/16 [==============================] - 0s 3ms/step - loss: 1.3730 - accuracy: 0.5063
# Epoch 5/100
# 16/16 [==============================] - 0s 3ms/step - loss: 1.2916 - accuracy: 0.4500
# Epoch 6/100
# 16/16 [==============================] - 0s 2ms/step - loss: 1.3149 - accuracy: 0.4875
# Epoch 7/100
# 16/16 [==============================] - 0s 2ms/step - loss: 1.2222 - accuracy: 0.5250
# Epoch 8/100
# 16/16 [==============================] - 0s 2ms/step - loss: 1.1156 - accuracy: 0.5312
# Epoch 9/100
# 16/16 [==============================] - 0s 2ms/step - loss: 1.1564 - accuracy: 0.5125
# Epoch 10/100
# 16/16 [==============================] - 0s 2ms/step - loss: 1.0873 - accuracy: 0.5312
# Epoch 11/100
# 16/16 [==============================] - 0s 2ms/step - loss: 1.0178 - accuracy: 0.6000
# Epoch 12/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.9166 - accuracy: 0.6938
# Epoch 13/100
# 16/16 [==============================] - 0s 2ms/step - loss: 1.0095 - accuracy: 0.6250
# Epoch 14/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.9925 - accuracy: 0.6000
# Epoch 15/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.7722 - accuracy: 0.7063
# Epoch 16/100
# 16/16 [==============================] - 0s 2ms/step - loss: 1.0277 - accuracy: 0.6187
# Epoch 17/100
# 16/16 [==============================] - 0s 2ms/step - loss: 1.0333 - accuracy: 0.6313
# Epoch 18/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.9938 - accuracy: 0.6250
# Epoch 19/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.8825 - accuracy: 0.6187
# Epoch 20/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.8286 - accuracy: 0.6750
# Epoch 21/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.8300 - accuracy: 0.6938
# Epoch 22/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.7997 - accuracy: 0.6938
# Epoch 23/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.9615 - accuracy: 0.6812
# Epoch 24/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.9657 - accuracy: 0.6625
# Epoch 25/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.9029 - accuracy: 0.6687
# Epoch 26/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.8907 - accuracy: 0.6750
# Epoch 27/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.9677 - accuracy: 0.6687
# Epoch 28/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.8664 - accuracy: 0.6938
# Epoch 29/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.7814 - accuracy: 0.7000
# Epoch 30/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.7775 - accuracy: 0.7000
# Epoch 31/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.7894 - accuracy: 0.6687
# Epoch 32/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6616 - accuracy: 0.7563
# Epoch 33/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.8058 - accuracy: 0.7000
# Epoch 34/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.8366 - accuracy: 0.6625
# Epoch 35/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5868 - accuracy: 0.8062
# Epoch 36/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.7376 - accuracy: 0.7063
# Epoch 37/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.7048 - accuracy: 0.7500
# Epoch 38/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.7115 - accuracy: 0.7312
# Epoch 39/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6401 - accuracy: 0.7625
# Epoch 40/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.7444 - accuracy: 0.7250
# Epoch 41/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.7571 - accuracy: 0.7000
# Epoch 42/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6887 - accuracy: 0.7437
# Epoch 43/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.7464 - accuracy: 0.7125
# Epoch 44/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.7992 - accuracy: 0.7063
# Epoch 45/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6750 - accuracy: 0.7063
# Epoch 46/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6989 - accuracy: 0.7563
# Epoch 47/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5836 - accuracy: 0.7875
# Epoch 48/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5628 - accuracy: 0.8062
# Epoch 49/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6638 - accuracy: 0.7375
# Epoch 50/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6461 - accuracy: 0.7937
# Epoch 51/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6342 - accuracy: 0.7625
# Epoch 52/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5508 - accuracy: 0.7812
# Epoch 53/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.7848 - accuracy: 0.7250
# Epoch 54/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.7795 - accuracy: 0.7437
# Epoch 55/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6983 - accuracy: 0.7563
# Epoch 56/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6706 - accuracy: 0.7625
# Epoch 57/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6115 - accuracy: 0.7625
# Epoch 58/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.7230 - accuracy: 0.7688
# Epoch 59/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5596 - accuracy: 0.8125
# Epoch 60/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.7439 - accuracy: 0.7563
# Epoch 61/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6357 - accuracy: 0.7500
# Epoch 62/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6258 - accuracy: 0.8000
# Epoch 63/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5128 - accuracy: 0.8188
# Epoch 64/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5933 - accuracy: 0.7750
# Epoch 65/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5492 - accuracy: 0.8250
# Epoch 66/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5248 - accuracy: 0.7875
# Epoch 67/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5360 - accuracy: 0.8062
# Epoch 68/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5161 - accuracy: 0.8062
# Epoch 69/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6334 - accuracy: 0.7437
# Epoch 70/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6221 - accuracy: 0.7750
# Epoch 71/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5387 - accuracy: 0.8000
# Epoch 72/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5817 - accuracy: 0.8188
# Epoch 73/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6828 - accuracy: 0.7312
# Epoch 74/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5350 - accuracy: 0.8062
# Epoch 75/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5081 - accuracy: 0.8000
# Epoch 76/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6131 - accuracy: 0.7875
# Epoch 77/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5430 - accuracy: 0.7937
# Epoch 78/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5631 - accuracy: 0.8062
# Epoch 79/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4689 - accuracy: 0.8188
# Epoch 80/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4186 - accuracy: 0.8687
# Epoch 81/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6349 - accuracy: 0.7688
# Epoch 82/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5670 - accuracy: 0.7875
# Epoch 83/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4720 - accuracy: 0.8125
# Epoch 84/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6153 - accuracy: 0.7875
# Epoch 85/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5796 - accuracy: 0.7937
# Epoch 86/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4644 - accuracy: 0.8562
# Epoch 87/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4691 - accuracy: 0.8375
# Epoch 88/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4684 - accuracy: 0.8313
# Epoch 89/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4611 - accuracy: 0.8250
# Epoch 90/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4604 - accuracy: 0.8375
# Epoch 91/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5639 - accuracy: 0.8062
# Epoch 92/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4771 - accuracy: 0.8375
# Epoch 93/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6193 - accuracy: 0.7375
# Epoch 94/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5156 - accuracy: 0.8188
# Epoch 95/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4713 - accuracy: 0.8500
# Epoch 96/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5804 - accuracy: 0.8062
# Epoch 97/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5577 - accuracy: 0.7750
# Epoch 98/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6158 - accuracy: 0.7563
# Epoch 99/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.5199 - accuracy: 0.8188
# Epoch 100/100
# 16/16 [==============================] - 0s 2ms/step - loss: 0.4346 - accuracy: 0.8313

# %%
##########################
# # get model accuracy # #
##########################
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

######################
# # get model loss # #
######################
plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %% [markdown]
# ### SAVE MODEL

# %%
##################
# # save model # #
##################

model.model.save("model/rnn_key_classifier.h5")

# %% [markdown]
# ### LOAD MODEL

# %%
# # ##################
# # # # load model # #
# # ##################

# model = create_model()
model = load_model("model/rnn_key_classifier.h5")

# %% [markdown]
# ### LIVE TESTING
# > * import any new data to perform testing and prediction

# %%
# import unseen data
pred_df = pd.read_csv(TEST_DATA_LINK)
pred_df['Subject'] = pred_df['Subject'].str.replace('@yopmail.com','')
pred_df['Subject'] = pred_df['Subject'].str.replace('@gmail.com','')
pred_df['Subject'] = pred_df['Subject'].str.replace('alithnks','ali')

column_to_reorder = pred_df.pop('Subject')

pred_df.insert(0, 'Subject', column_to_reorder)
pred_df.head()
# Out:
#   Subject                __id__        AvA       AvH       AvP  `DD.0.5`  \
# 0   aisha  32EyOh61auQrtt845qqu  30.386073  0.117320  0.207566  0.316371
# 1   aisha  4bA0GNx1E4csaTigdnUk  29.442656  0.117420  0.212496  0.349458
# 2   aisha  8XMHJ2b4PLrT9XU667dv  29.863961  0.098838  0.219027  0.282859
# 3     ali  x1FEHtJP9xDxTOeMGxGD  29.888982  0.088453  0.324981  0.267652
# 4     ali  y5GzBnwpg43QOeOzQ28R  27.805260  0.077486  0.211683  0.233024
#
#    `DD.1.6`  `DD.2.4`  `DD.4.8`  `DD.5.2`  ...   `Size.9`  `UD.0.5`  `UD.1.6`  \
# 0  0.525669  0.183837  0.574917  1.299633  ...  29.588976  0.316371  0.525669
# 1  3.484031  0.219371  0.813483  0.342324  ...  24.210612  0.349458  3.484031
# 2  0.284138  0.192723  0.191222  0.224901  ...  28.748535  0.282859  0.284138
# 3  0.215470  0.123510  0.207815  0.200449  ...  27.667969  0.267652  0.215470
# 4  0.932978  0.163148  0.449982  0.194738  ...  27.667969  0.233024  0.932978
#
#    `UD.2.4`  `UD.4.8`  `UD.5.2`  `UD.6.7`  `UD.7.9`  `UD.8.1`  `UD.9.3`
# 0  0.183837  0.574917  1.299633  0.333369  1.700769  0.949691  0.607718
# 1  0.219371  0.813483  0.342324  0.608039  0.625773  0.416927  0.908202
# 2  0.192723  0.191222  0.224901  0.232967  0.466518  0.207866  0.426501
# 3  0.123510  0.207815  0.200449  0.117066  0.200477  0.143154  0.207918
# 4  0.163148  0.449982  0.194738  0.165819  0.199959  0.192599  0.201954
#
# [5 rows x 53 columns]

# %%
################################
# # check for class validity # #
################################
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="Subject", data=pred_df).set_title("Class Validity")

# remove missing values if available
pred_df = pred_df.dropna()

# %%
pred_dataset = pred_df.values

# # divide data into features X
# pred_row = pred_dataset[:,3:].astype(float)

#################################
# # predict more than one row # #
#################################

# pred_row=pred_df.iloc[:,3:]

# print(pred_row)
############################
# # predict a single row # #
############################

pred_row=pred_df.iloc[1:,2:]

################################
# # normalise and shape data # #
################################
pred_row = pred_row.values.tolist()
# pred_row = scaler.transform(pred_row)
pred_arr = np.asarray(pred_row, dtype=np.float32)
pred_arr = np.reshape(pred_arr, (pred_arr.shape[0], TIMESTEPS, pred_arr.shape[1]))

# %%
####################################
# # get prediction and its label # #
####################################

pred_proba = model.predict_proba(pred_arr)
pred = lb.inverse_transform(pred_proba)
acc = np.max(pred_proba, axis=1)

pred_results = np.column_stack((pred, acc))

df = pd.DataFrame(data=pred_results, index=None, columns=['Prediction', 'Accuracy'])
print(df)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x15b9d8ee0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 308ms/step
#    Prediction    Accuracy
# 0        umer   0.5617309
# 1       aisha  0.44516447
# 2         ali  0.96479034
# 3         ali  0.97297704
# 4         ali    0.987648
# 5       ramla  0.99932885
# 6       ramla  0.99348515
# 7       ramla   0.9992853
# 8        saad   0.9970919
# 9        saad  0.99502254
# 10       saad  0.99801576
# 11       umer  0.97944194
# 12       umer  0.94787323
# 13       umer   0.9602694
